# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding='ISO-8859-1')
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 1391  ham                Haha just kidding, papa needs drugs        NaN
# 3083  ham  Ok lor. I ned 2 go toa payoh 4 a while 2 retur...        NaN
# 1745  ham  IåÕm cool ta luv but v.tired 2 cause i have be...        NaN
# 253   ham  Ups which is 3days also, and the shipping comp...        NaN
# 3452  ham  Nowadays people are notixiquating the laxinorf...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1391        NaN        NaN
# 3083        NaN        NaN
# 1745        NaN        NaN
# 253         NaN        NaN
# 3452        NaN        NaN

# %%
df.head(10)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6   ham  Even my brother is not like to speak with me. ...        NaN
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8  spam  WINNER!! As a valued network customer you have...        NaN
# 9  spam  Had your mobile 11 months or more? U R entitle...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# ...

# %%
df.tail(10)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5562   ham  Ok lor... Sony ericsson salesman... I ask shuh...        NaN
# 5563   ham                                Ard 6 like dat lor.        NaN
# 5564   ham  Why don't you wait 'til at least wednesday to ...        NaN
# 5565   ham                                       Huh y lei...        NaN
# 5566  spam  REMINDER FROM O2: To get 2.50 pounds free call...        NaN
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5562        NaN        NaN
# 5563        NaN        NaN
# 5564        NaN        NaN
# 5565        NaN        NaN
# ...

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.head(10)
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...
# 6   ham  Even my brother is not like to speak with me. ...
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...
# 8  spam  WINNER!! As a valued network customer you have...
# 9  spam  Had your mobile 11 months or more? U R entitle...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['v1']=encoder.fit_transform(df['v1'])

# %%
df.head(10)
# Out:
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...
# 5   1  FreeMsg Hey there darling it's been 3 week's n...
# 6   0  Even my brother is not like to speak with me. ...
# 7   0  As per your request 'Melle Melle (Oru Minnamin...
# 8   1  WINNER!! As a valued network customer you have...
# 9   1  Had your mobile 11 months or more? U R entitle...

# %%
df.isnull()
# Out:
#          v1     v2
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ...     ...    ...
# 5567  False  False
# 5568  False  False
# 5569  False  False
# 5570  False  False
# 5571  False  False
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# v1    0
# v2    0
# dtype: int64

# %%
df=df.drop_duplicates(keep='first')
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # EDA

# %%
df['v1'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: v1, dtype: int64

# %%
plt.pie(df['v1'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
plt.show()

# %%
import nltk

# %%
# !pip install nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df['no_of_chars']=df['v2'].apply(len)
df.head()
# Out:
#    v1                                                 v2  no_of_chars
# 0   0  Go until jurong point, crazy.. Available only ...          111
# 1   0                      Ok lar... Joking wif u oni...           29
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3   0  U dun say so early hor... U c already then say...           49
# 4   0  Nah I don't think he goes to usf, he lives aro...           61

# %%
df['no_of_words']=df['v2'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    v1                                                 v2  no_of_chars  \
# 0   0  Go until jurong point, crazy.. Available only ...          111
# 1   0                      Ok lar... Joking wif u oni...           29
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3   0  U dun say so early hor... U c already then say...           49
# 4   0  Nah I don't think he goes to usf, he lives aro...           61
#
#    no_of_words
# 0           24
# 1            8
# 2           37
# 3           13
# 4           15

# %%
df['no_of_sentences']=df['v2'].apply(lambda x:len(nltk.sent_tokenize(x)))
df.head()
# Out:
#    v1                                                 v2  no_of_chars  \
# 0   0  Go until jurong point, crazy.. Available only ...          111
# 1   0                      Ok lar... Joking wif u oni...           29
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3   0  U dun say so early hor... U c already then say...           49
# 4   0  Nah I don't think he goes to usf, he lives aro...           61
#
#    no_of_words  no_of_sentences
# 0           24                2
# 1            8                2
# 2           37                2
# 3           13                1
# 4           15                1

# %%
df[['no_of_chars','no_of_words','no_of_sentences']].describe()
# Out:
#        no_of_chars  no_of_words  no_of_sentences
# count  5169.000000  5169.000000      5169.000000
# mean     78.977945    18.455794         1.965564
# std      58.236293    13.324758         1.448541
# min       2.000000     1.000000         1.000000
# 25%      36.000000     9.000000         1.000000
# 50%      60.000000    15.000000         1.000000
# 75%     117.000000    26.000000         2.000000
# max     910.000000   220.000000        38.000000

# %%
df[['no_of_chars','no_of_words','no_of_sentences']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5169 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   no_of_chars      5169 non-null   int64
#  1   no_of_words      5169 non-null   int64
#  2   no_of_sentences  5169 non-null   int64
# dtypes: int64(3)
# memory usage: 161.5 KB

# %%
df[df['v1']==1][['no_of_chars','no_of_words','no_of_sentences']].describe()
# Out:
#        no_of_chars  no_of_words  no_of_sentences
# count   653.000000   653.000000       653.000000
# mean    137.891271    27.667688         2.970904
# std      30.137753     7.008418         1.488425
# min      13.000000     2.000000         1.000000
# 25%     132.000000    25.000000         2.000000
# 50%     149.000000    29.000000         3.000000
# 75%     157.000000    32.000000         4.000000
# max     224.000000    46.000000         9.000000

# %%
df[df['v1']==0][['no_of_chars','no_of_words','no_of_sentences']].describe()
# Out:
#        no_of_chars  no_of_words  no_of_sentences
# count  4516.000000  4516.000000      4516.000000
# mean     70.459256    17.123782         1.820195
# std      56.358207    13.493970         1.383657
# min       2.000000     1.000000         1.000000
# 25%      34.000000     8.000000         1.000000
# 50%      52.000000    13.000000         1.000000
# 75%      90.000000    22.000000         2.000000
# max     910.000000   220.000000        38.000000

# %%
import seaborn as sns
sns.histplot(df[df['v1']==0]['no_of_chars'])
sns.histplot(df[df['v1']==1]['no_of_chars'],color='Red')
# Out:
# <Axes: xlabel='no_of_chars', ylabel='Count'>

# %%
sns.histplot(df[df['v1']==0]['no_of_words'])
sns.histplot(df[df['v1']==1]['no_of_words'],color='Red')
# Out:
# <Axes: xlabel='no_of_words', ylabel='Count'>

# %%
sns.histplot(df[df['v1']==0]['no_of_sentences'])
sns.histplot(df[df['v1']==1]['no_of_sentences'],color='Red')
# Out:
# <Axes: xlabel='no_of_sentences', ylabel='Count'>

# %%
sns.pairplot(df,hue='v1')
plt.show()

# %%
df[['v1','no_of_chars','no_of_words','no_of_sentences']].corr()
# Out:
#                        v1  no_of_chars  no_of_words  no_of_sentences
# v1               1.000000     0.384717     0.262912         0.263939
# no_of_chars      0.384717     1.000000     0.965760         0.624139
# no_of_words      0.262912     0.965760     1.000000         0.679971
# no_of_sentences  0.263939     0.624139     0.679971         1.000000

# %%
sns.heatmap(df[['v1','no_of_chars','no_of_words','no_of_sentences']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # DATA PREPROCESSING

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def changetext(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    x=[]
    for i in text:
        if i.isalnum():
            x.append(i)
    text=x[:]
    x.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            x.append(i)
    text=x[:]
    x.clear()
    for i in text:
        x.append(ps.stem(i))
    return " ".join(x)

# %%
changetext('hi my name is mahesh!')
# Out:
# 'hi name mahesh'

# %%
df['newtext']=df['v2'].apply(changetext)

# %%
df.head()
# Out:
#    v1                                                 v2  no_of_chars  \
# 0   0  Go until jurong point, crazy.. Available only ...          111
# 1   0                      Ok lar... Joking wif u oni...           29
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3   0  U dun say so early hor... U c already then say...           49
# 4   0  Nah I don't think he goes to usf, he lives aro...           61
#
#    no_of_words  no_of_sentences  \
# 0           24                2
# 1            8                2
# 2           37                2
# 3           13                1
# 4           15                1
#
#                                              newtext
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc=WordCloud(height=750,width=750,min_font_size=10)

# %%
spam_wc=wc.generate(df[df['v1']==1]['newtext'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['v1']==0]['newtext'].str.cat(sep=" "))
plt.imshow(ham_wc)

# %%
from collections import Counter

# %%
spam_words=[]
for msg in df[df['v1']==1]['newtext'].tolist():
    for word in msg.split():
        spam_words.append(word)
spam_words_count=pd.DataFrame(Counter(spam_words).most_common(50),columns=['Word', 'Count'])

# %%
sns.barplot(x='Count', y='Word', data=spam_words_count)
plt.show()

# %%
ham_words=[]
for msg in df[df['v1']==0]['newtext'].tolist():
    for word in msg.split():
        ham_words.append(word)
ham_words_count=pd.DataFrame(Counter(ham_words).most_common(50),columns=['Word', 'Count'])
sns.barplot(x='Count', y='Word', data=ham_words_count)
plt.show()

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['newtext']).toarray()
X.shape
# Out:
# (5169, 3000)

# %%
y=df['v1'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
